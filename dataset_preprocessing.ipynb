# %% [markdown]
# # Covid-19 X-Ray Data Preprocessing

# %%
import pandas as pd
import os
import shutil
import random
import datetime as dt

# %% [markdown]
# Process images of positive Covid-19 sample set (Github)
# Link: https://github.com/ieee8023/covid-chestxray-dataset
#
# We have taken the Covid images as of July 31st, 2020. This image set is updated regularly.

# %% [markdown]
# ## Sampling Github X-Ray Images of Covid-19 Patients

# %% [markdown]
# We first download the metadata file which contains the breakdown of filename, diagnosis (not all images are Covid), and view. We are interested in the PA (posteroanterior) view only.

# %%
metadata_url_latest = "https://raw.githubusercontent.com/ieee8023/covid-chestxray-dataset/master/metadata.csv"
metadata_url = "https://raw.githubusercontent.com/ieee8023/covid-chestxray-dataset/59d85dfc206cf5159fd3f1a1cb5e2727ed95eac3/metadata.csv"
df_metadata = pd.read_csv(metadata_url)
print(df_metadata.shape)
# Out:
# (877, 29)

# %%
df_metadata.head()
# Out:
#   patientid  offset sex   age   finding RT_PCR_positive survival intubated  \
# 0         2     0.0   M  65.0  COVID-19               Y        Y         N
# 1         2     3.0   M  65.0  COVID-19               Y        Y         N
# 2         2     5.0   M  65.0  COVID-19               Y        Y         N
# 3         2     6.0   M  65.0  COVID-19               Y        Y         N
# 4         4     0.0   F  52.0  COVID-19               Y      NaN         N
#
#   intubation_present went_icu  ... modality              date  \
# 0                  N        N  ...    X-ray  January 22, 2020
# 1                  N        N  ...    X-ray  January 25, 2020
# 2                  N        N  ...    X-ray  January 27, 2020
# 3                  N        N  ...    X-ray  January 28, 2020
# 4                  N        N  ...    X-ray  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Ta...  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN
# 1  On January 22, 2020, a 65-year-old man with a ...         NaN
# 2  On January 22, 2020, a 65-year-old man with a ...         NaN
# 3  On January 22, 2020, a 65-year-old man with a ...         NaN
# 4   diffuse infiltrates in the bilateral lower lungs         NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Create the Training Dataset for Covid Images

# %%
covid_raw = r"C:\Users\vijay\OneDrive\Documents\Projects\Covid19-Xray-Detection\raw\covid-chestxray-dataset-master\images"
dest_dir = r"C:\Users\vijay\OneDrive\Documents\Projects\Covid19-Xray-Detection\Covid_Dataset\Training\Covid"

if not os.path.exists(dest_dir):
    os.mkdir(dest_dir)
    print("Covid X-ray folder created")
else:
        print("Folder already exists!")
# Out:
# Covid X-ray folder created

# %% [markdown]
# In the next step, we will loop over all raw images based on covid classification, which are Posteroanterior (beams pass from back-to-front). This is determined by using the metadata file. These images are moved into a new dataset folder based on the criteria.
#
# We see below that there are 204 covid-19 classified images with the PA view.

# %%
df_metadata[(df_metadata["finding"]=="COVID-19") & (df_metadata["view"]=="PA")]
# Out:
#     patientid  offset sex   age   finding RT_PCR_positive survival intubated  \
# 0           2     0.0   M  65.0  COVID-19               Y        Y         N
# 1           2     3.0   M  65.0  COVID-19               Y        Y         N
# 2           2     5.0   M  65.0  COVID-19               Y        Y         N
# 3           2     6.0   M  65.0  COVID-19               Y        Y         N
# 4           4     0.0   F  52.0  COVID-19               Y      NaN         N
# ..        ...     ...  ..   ...       ...             ...      ...       ...
# 651       347     3.0   F  39.0  COVID-19             NaN        Y         N
# 653       347    13.0   F  39.0  COVID-19             NaN        Y         N
# 659      350b     4.0   M  30.0  COVID-19             NaN      NaN       NaN
# 666       355     NaN   M  40.0  COVID-19             NaN      NaN       NaN
# 673       358     0.0   F  25.0  COVID-19             NaN        Y       NaN
#
#     intubation_present went_icu  ... modality              date  \
# 0                    N        N  ...    X-ray  January 22, 2020
# 1                    N        N  ...    X-ray  January 25, 2020
# 2                    N        N  ...    X-ray  January 27, 2020
# 3                    N        N  ...    X-ray  January 28, 2020
# 4                    N        N  ...    X-ray  January 25, 2020
# ..                 ...      ...  ...      ...               ...
# 651                  N        N  ...    X-ray              2020
# 653                  N        N  ...    X-ray              2020
# 659                NaN      NaN  ...    X-ray              2020
# 666                NaN        Y  ...    X-ray              2020
# 673                NaN      NaN  ...    X-ray              2020
#
#                                               location  folder  \
# 0          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3          Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4    Changhua Christian Hospital, Changhua City, Ta...  images
# ..                                                 ...     ...
# 651                                              Italy  images
# 653                                              Italy  images
# 659                                        Doha, Qatar  images
# 666                                        Doha, Qatar  images
# 673                                       Tehran, Iran  images
#
#                                               filename                   doi  \
# 0    auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1    auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2    auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3    auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                                nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
# ..                                                 ...                   ...
# 651                          covid-19-caso-95-1-15.png                   NaN
# 653                          covid-19-caso-95-3-14.png                   NaN
# 659          1141cc2b8b9cc394becce5d978b5a7_jumbo.jpeg                   NaN
# 666          14d81f378173b86cc53f21d2d67040_jumbo.jpeg                   NaN
# 673          b0f1684d1ee90dc09deef015e29dae_jumbo.jpeg                   NaN
#
#                                                    url      license  \
# 0    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 1    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 2    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 3    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# 4    https://www.nejm.org/doi/full/10.1056/NEJMc200...          NaN
# ..                                                 ...          ...
# 651  https://www.sirm.org/2020/05/20/covid-19-caso-95/          NaN
# 653  https://www.sirm.org/2020/05/20/covid-19-caso-95/          NaN
# 659  https://radiopaedia.org/cases/covid-19-18?lang=us  CC BY-NC-SA
# 666  https://radiopaedia.org/cases/covid-19-pneumon...  CC BY-NC-SA
# 673  https://radiopaedia.org/cases/covid-19-pneumon...  CC BY-NC-SA
#
#                                         clinical_notes  \
# 0    On January 22, 2020, a 65-year-old man with a ...
# 1    On January 22, 2020, a 65-year-old man with a ...
# 2    On January 22, 2020, a 65-year-old man with a ...
# 3    On January 22, 2020, a 65-year-old man with a ...
# 4     diffuse infiltrates in the bilateral lower lungs
# ..                                                 ...
# 651                                                NaN
# 653  Plenty of nuanced shaded glass areola are appr...
# 659  Presentation: Four days history of fever. Imag...
# 666  Presentation: Three days of high-grade fever w...
# 673  A young female with fever and also her brother...
#
#                                            other_notes
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 651                                                NaN
# 653  Credit to Davide Stoppa, Federico Paltenghi, L...
# 659  Case courtesy of Dr Salah Aljilly, Radiopaedia...
# 666  Case courtesy of Dr Salah Aljilly, Radiopaedia...
# 673  Case courtesy of Dr Bahman Rasuli, Radiopaedia...
#
# [180 rows x 29 columns]

# %%
count = 0

for (i,row) in df_metadata.iterrows():
    if row["finding"]=="COVID-19" and row["view"]=="PA":
        filename = row["filename"]
        img_orig_filepath = os.path.join(covid_raw, filename)
        img_new_filepath = os.path.join(dest_dir,filename)
        shutil.copy2(img_orig_filepath, img_new_filepath)
        print("Copying image to new path", count+1)
        count +=1
print(count)
# Out:
# Copying image to new path 1
# Copying image to new path 2
# Copying image to new path 3
# Copying image to new path 4
# Copying image to new path 5
# Copying image to new path 6
# Copying image to new path 7
# Copying image to new path 8
# Copying image to new path 9
# Copying image to new path 10
# Copying image to new path 11
# Copying image to new path 12
# Copying image to new path 13
# Copying image to new path 14
# Copying image to new path 15
# Copying image to new path 16
# Copying image to new path 17
# Copying image to new path 18
# Copying image to new path 19
# Copying image to new path 20
# Copying image to new path 21
# Copying image to new path 22
# Copying image to new path 23
# Copying image to new path 24
# Copying image to new path 25
# Copying image to new path 26
# Copying image to new path 27
# Copying image to new path 28
# Copying image to new path 29
# Copying image to new path 30
# Copying image to new path 31
# Copying image to new path 32
# Copying image to new path 33
# Copying image to new path 34
# Copying image to new path 35
# Copying image to new path 36
# Copying image to new path 37
# Copying image to new path 38
# Copying image to new path 39
# Copying image to new path 40
# Copying image to new path 41
# Copying image to new path 42
# Copying image to new path 43
# Copying image to new path 44
# Copying image to new path 45
# Copying image to new path 46
# Copying image to new path 47
# Copying image to new path 48
# Copying image to new path 49
# Copying image to new path 50
# Copying image to new path 51
# Copying image to new path 52
# Copying image to new path 53
# Copying image to new path 54
# Copying image to new path 55
# Copying image to new path 56
# Copying image to new path 57
# Copying image to new path 58
# Copying image to new path 59
# Copying image to new path 60
# Copying image to new path 61
# Copying image to new path 62
# Copying image to new path 63
# Copying image to new path 64
# Copying image to new path 65
# Copying image to new path 66
# Copying image to new path 67
# Copying image to new path 68
# Copying image to new path 69
# Copying image to new path 70
# Copying image to new path 71
# Copying image to new path 72
# Copying image to new path 73
# Copying image to new path 74
# Copying image to new path 75
# Copying image to new path 76
# Copying image to new path 77
# Copying image to new path 78
# Copying image to new path 79
# Copying image to new path 80
# Copying image to new path 81
# Copying image to new path 82
# Copying image to new path 83
# Copying image to new path 84
# Copying image to new path 85
# Copying image to new path 86
# Copying image to new path 87
# Copying image to new path 88
# Copying image to new path 89
# Copying image to new path 90
# Copying image to new path 91
# Copying image to new path 92
# Copying image to new path 93
# Copying image to new path 94
# Copying image to new path 95
# Copying image to new path 96
# Copying image to new path 97
# Copying image to new path 98
# Copying image to new path 99
# Copying image to new path 100
# Copying image to new path 101
# Copying image to new path 102
# Copying image to new path 103
# Copying image to new path 104
# Copying image to new path 105
# Copying image to new path 106
# Copying image to new path 107
# Copying image to new path 108
# Copying image to new path 109
# Copying image to new path 110
# Copying image to new path 111
# Copying image to new path 112
# Copying image to new path 113
# Copying image to new path 114
# Copying image to new path 115
# Copying image to new path 116
# Copying image to new path 117
# Copying image to new path 118
# Copying image to new path 119
# Copying image to new path 120
# Copying image to new path 121
# Copying image to new path 122
# Copying image to new path 123
# Copying image to new path 124
# Copying image to new path 125
# Copying image to new path 126
# Copying image to new path 127
# Copying image to new path 128
# Copying image to new path 129
# Copying image to new path 130
# Copying image to new path 131
# Copying image to new path 132
# Copying image to new path 133
# Copying image to new path 134
# Copying image to new path 135
# Copying image to new path 136
# Copying image to new path 137
# Copying image to new path 138
# Copying image to new path 139
# Copying image to new path 140
# Copying image to new path 141
# Copying image to new path 142
# Copying image to new path 143
# Copying image to new path 144
# Copying image to new path 145
# Copying image to new path 146
# Copying image to new path 147
# Copying image to new path 148
# Copying image to new path 149
# Copying image to new path 150
# Copying image to new path 151
# Copying image to new path 152
# Copying image to new path 153
# Copying image to new path 154
# Copying image to new path 155
# Copying image to new path 156
# Copying image to new path 157
# Copying image to new path 158
# Copying image to new path 159
# Copying image to new path 160
# Copying image to new path 161
# Copying image to new path 162
# Copying image to new path 163
# Copying image to new path 164
# Copying image to new path 165
# Copying image to new path 166
# Copying image to new path 167
# Copying image to new path 168
# Copying image to new path 169
# Copying image to new path 170
# Copying image to new path 171
# Copying image to new path 172
# Copying image to new path 173
# Copying image to new path 174
# Copying image to new path 175
# Copying image to new path 176
# Copying image to new path 177
# Copying image to new path 178
# Copying image to new path 179
# Copying image to new path 180
# 180

# %%
print(count)
# Out:
# 180

# %% [markdown]
# ## Sampling Kaggle X-Ray Images of Normal Lungs

# %% [markdown]
# These X-Ray images have been taken from https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia

# %%
kaggle_raw = r"C:\Users\vijay\Downloads\17810_23812_bundle_archive\chest_xray\train\NORMAL"
kaggle_dest_dir = r"C:\Users\vijay\OneDrive\Documents\Projects\Covid19-Xray-Detection\Covid_Dataset\Training\Normal"

# %%
# randomly shuffle the images and sample from
img_names = os.listdir(kaggle_raw)
random.shuffle(img_names)

# %%
# check if desination folder exists
if not os.path.exists(kaggle_dest_dir):
    os.mkdir(kaggle_dest_dir)
    print("Normal X-ray folder created")
else:
        print("Folder already exists!")
# Out:
# Normal X-ray folder created

# %%
for i in range(count):
    img_name = img_names[i]
    img_dest = os.path.join(kaggle_raw, img_name)
    img_target_dir = os.path.join(kaggle_dest_dir, img_name)
    shutil.copy2(img_dest, img_target_dir)
    print("Copying normal xray image", i+1)
# Out:
# Copying normal xray image 1
# Copying normal xray image 2
# Copying normal xray image 3
# Copying normal xray image 4
# Copying normal xray image 5
# Copying normal xray image 6
# Copying normal xray image 7
# Copying normal xray image 8
# Copying normal xray image 9
# Copying normal xray image 10
# Copying normal xray image 11
# Copying normal xray image 12
# Copying normal xray image 13
# Copying normal xray image 14
# Copying normal xray image 15
# Copying normal xray image 16
# Copying normal xray image 17
# Copying normal xray image 18
# Copying normal xray image 19
# Copying normal xray image 20
# Copying normal xray image 21
# Copying normal xray image 22
# Copying normal xray image 23
# Copying normal xray image 24
# Copying normal xray image 25
# Copying normal xray image 26
# Copying normal xray image 27
# Copying normal xray image 28
# Copying normal xray image 29
# Copying normal xray image 30
# Copying normal xray image 31
# Copying normal xray image 32
# Copying normal xray image 33
# Copying normal xray image 34
# Copying normal xray image 35
# Copying normal xray image 36
# Copying normal xray image 37
# Copying normal xray image 38
# Copying normal xray image 39
# Copying normal xray image 40
# Copying normal xray image 41
# Copying normal xray image 42
# Copying normal xray image 43
# Copying normal xray image 44
# Copying normal xray image 45
# Copying normal xray image 46
# Copying normal xray image 47
# Copying normal xray image 48
# Copying normal xray image 49
# Copying normal xray image 50
# Copying normal xray image 51
# Copying normal xray image 52
# Copying normal xray image 53
# Copying normal xray image 54
# Copying normal xray image 55
# Copying normal xray image 56
# Copying normal xray image 57
# Copying normal xray image 58
# Copying normal xray image 59
# Copying normal xray image 60
# Copying normal xray image 61
# Copying normal xray image 62
# Copying normal xray image 63
# Copying normal xray image 64
# Copying normal xray image 65
# Copying normal xray image 66
# Copying normal xray image 67
# Copying normal xray image 68
# Copying normal xray image 69
# Copying normal xray image 70
# Copying normal xray image 71
# Copying normal xray image 72
# Copying normal xray image 73
# Copying normal xray image 74
# Copying normal xray image 75
# Copying normal xray image 76
# Copying normal xray image 77
# Copying normal xray image 78
# Copying normal xray image 79
# Copying normal xray image 80
# Copying normal xray image 81
# Copying normal xray image 82
# Copying normal xray image 83
# Copying normal xray image 84
# Copying normal xray image 85
# Copying normal xray image 86
# Copying normal xray image 87
# Copying normal xray image 88
# Copying normal xray image 89
# Copying normal xray image 90
# Copying normal xray image 91
# Copying normal xray image 92
# Copying normal xray image 93
# Copying normal xray image 94
# Copying normal xray image 95
# Copying normal xray image 96
# Copying normal xray image 97
# Copying normal xray image 98
# Copying normal xray image 99
# Copying normal xray image 100
# Copying normal xray image 101
# Copying normal xray image 102
# Copying normal xray image 103
# Copying normal xray image 104
# Copying normal xray image 105
# Copying normal xray image 106
# Copying normal xray image 107
# Copying normal xray image 108
# Copying normal xray image 109
# Copying normal xray image 110
# Copying normal xray image 111
# Copying normal xray image 112
# Copying normal xray image 113
# Copying normal xray image 114
# Copying normal xray image 115
# Copying normal xray image 116
# Copying normal xray image 117
# Copying normal xray image 118
# Copying normal xray image 119
# Copying normal xray image 120
# Copying normal xray image 121
# Copying normal xray image 122
# Copying normal xray image 123
# Copying normal xray image 124
# Copying normal xray image 125
# Copying normal xray image 126
# Copying normal xray image 127
# Copying normal xray image 128
# Copying normal xray image 129
# Copying normal xray image 130
# Copying normal xray image 131
# Copying normal xray image 132
# Copying normal xray image 133
# Copying normal xray image 134
# Copying normal xray image 135
# Copying normal xray image 136
# Copying normal xray image 137
# Copying normal xray image 138
# Copying normal xray image 139
# Copying normal xray image 140
# Copying normal xray image 141
# Copying normal xray image 142
# Copying normal xray image 143
# Copying normal xray image 144
# Copying normal xray image 145
# Copying normal xray image 146
# Copying normal xray image 147
# Copying normal xray image 148
# Copying normal xray image 149
# Copying normal xray image 150
# Copying normal xray image 151
# Copying normal xray image 152
# Copying normal xray image 153
# Copying normal xray image 154
# Copying normal xray image 155
# Copying normal xray image 156
# Copying normal xray image 157
# Copying normal xray image 158
# Copying normal xray image 159
# Copying normal xray image 160
# Copying normal xray image 161
# Copying normal xray image 162
# Copying normal xray image 163
# Copying normal xray image 164
# Copying normal xray image 165
# Copying normal xray image 166
# Copying normal xray image 167
# Copying normal xray image 168
# Copying normal xray image 169
# Copying normal xray image 170
# Copying normal xray image 171
# Copying normal xray image 172
# Copying normal xray image 173
# Copying normal xray image 174
# Copying normal xray image 175
# Copying normal xray image 176
# Copying normal xray image 177
# Copying normal xray image 178
# Copying normal xray image 179
# Copying normal xray image 180

# %% [markdown]
# In order to create the testing set, we will use the 80/20 split of the Normal and Covid images into a separate folder.
# The final breakdown is as follows:
#
# *  Training: 144 images for each category (Covid & Normal)
# *  Testing: 36 images for each category
#
# We will now proceed to loading the images into Google Colab and training a CNN!
